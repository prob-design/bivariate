# %%
from src.class_multivar import Bivariate, Multivariate
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st

# %%
from scipy.stats import multivariate_normal as mvn
from scipy.optimize import fsolve

# %%
X1 = st.norm(0,1)
X2 = st.norm(1,0.3)
X3 = st.norm(3,1.7)

# %% [markdown]
# ## Bivariate class

# %%
B12 = Bivariate(X1, X2, "Normal", 0.5)

# %%
B12.drawMarginalCdf(0)
# Out:
# (<Figure size 1200x800 with 1 Axes>,
#  <Axes: title={'center': 'Cumulative density function of $X_{0}$'}, xlabel='$F(X_0})$'>)

# %%
a = [5]
a.insert(0, 4)
print(a)
# Out:
# [4, 5]

# %%
def myLSF(x):
    return x[0]**2 - x[1] +2

# Due to the symmetry of the square function in 0, the default start=0 leads to no convergence
B12.pointLSF(myLSF, 1, 9)
# Out:
# 81.0

# %%
f, ax = plt.subplots(ncols=2, figsize=(20, 10))
B12.plotLSF(myLSF, ax=ax[0])
B12.plotLSF(myLSF, ax=ax[1], reverse=True)
# Out:
# (<Figure size 2000x1000 with 2 Axes>, <Axes: >)

# %%
# B12.plot_contour(ax[0])
# B12.plot_contour(ax[1], reverse=True)

# f

# %% [markdown]
# ## Multivariate class

# %%
M = Multivariate([X1, X2, X3], [("Normal", 0.5), ("Normal", 0.75)])

# %%
M.drawMarginalPdf(1)
# Out:
# (<Figure size 1200x800 with 1 Axes>,
#  <Axes: title={'center': 'Probability density function of $X_{1}$'}, xlabel='$X_1}$', ylabel='f($X_1})$'>)

# %%
M.bivariate_plot(2,1, myLSF)
# Out:
# c:\Users\benja\Documents\TU Delft\Year 2\Teaching Assistant\bivariate_package\src\class_multivar.py:20: RuntimeWarning: invalid value encountered in double_scalars
#   pdf = 1/(2*np.pi*np.sqrt(1-rho**2)) * np.exp(-(x**2 - 2*rho*x*y + y**2)/(2*(1-rho**2)))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 M.bivariate_plot(2,1, myLSF)
#
# File c:\Users\benja\Documents\TU Delft\Year 2\Teaching Assistant\bivariate_package\src\class_multivar.py:301, in Multivariate.bivariate_plot(self, x_index, y_index, myLSF)
#     298 ax.set_ylabel(fr"$X_{{{y_index}}}$", fontsize=18)
#     299 #ax.set_xlim(x[0], x[-1])
#     300 #ax.set_ylim(Y.ppf(0.01), Y.ppf(0.99))
# --> 301 ax.set_aspect("scaled")
#     302 return f, ax
#
# File c:\Users\benja\.conda\envs\bivariate\lib\site-packages\matplotlib\axes\_base.py:1667, in _AxesBase.set_aspect(self, aspect, adjustable, anchor, share)
#    1665     aspect = 1
#    1666 if not cbook._str_equal(aspect, 'auto'):
# -> 1667     aspect = float(aspect)  # raise ValueError if necessary
#    1668     if aspect <= 0 or not np.isfinite(aspect):
#    1669         raise ValueError("aspect must be finite and positive ")
#
# ValueError: could not convert string to float: 'scaled'
